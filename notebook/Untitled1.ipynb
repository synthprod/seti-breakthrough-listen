# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
train_df = pd.read_csv("../train_labels.csv")

# %%
train_df[train_df["id"] == "001c619bdf53"]
# Out:
#               id  target                 file_path  fold
# 20  001c619bdf53       1  train/0/001c619bdf53.npy     3

# %%
# idx = 0
# image = np.load("../" + train_df.loc[idx, "file_path"])
image = np.load("../train/0/001c619bdf53.npy")
# image = np.load("../train/2/2503d7f6e5c4.npy")
image = image.astype(np.float32)
image = np.vstack(image).transpose((1, 0))
image.shape
# Out:
# (256, 1638)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(image)
plt.show()

# %%
resized = cv2.resize(image, (1024, 512))
print(resized.shape)
plt.figure(figsize=(20, 20))
plt.imshow(resized)
plt.show()
# Out:
# (512, 1024)

# %%
resized = cv2.resize(image, (512, 1024))
print(resized.shape)
plt.figure(figsize=(20, 20))
plt.imshow(resized)
plt.show()
# Out:
# (1024, 512)
